# %%
#1.Preparing our dataset

# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv('datasets/fma-rock-vs-hiphop.csv')
# Read in track metrics with the features
echonest_metrics = pd.read_json('datasets/echonest-metrics.json',
                               precise_float = True)

# %%
tracks.head()
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
#
#          date_recorded  duration  favorites genre_top    genres  ...  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]  ...
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]  ...
# 2                  NaN       192          0      Rock      [25]  ...
# 3                  NaN       193          0      Rock      [25]  ...
# 4  2008-11-26 00:00:00       405          5      Rock      [26]  ...
#
#   information interest  language_code  \
# 0         NaN     2484             en
# 1         NaN     1948             en
# 2         NaN      701             en
# 3         NaN      637             en
# 4         NaN      354             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN     11
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN      2
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
# 3        NaN   []                 Untitled 11
# 4        NaN   []          Hundred-Year Flood
#
# [5 rows x 21 columns]

# %%
echonest_metrics.head()
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3        10      0.951670      0.658179  0.924525          0.965427  0.115474
# 4       134      0.452217      0.513238  0.560410          0.019443  0.096567
#
#    speechiness    tempo   valence
# 0     0.159310  165.922  0.576661
# 1     0.461818  126.957  0.269240
# 2     0.124595  100.260  0.621661
# 3     0.032985  111.562  0.963590
# 4     0.525519  114.290  0.894072

# %%
# Merge the track_id and genre_top columns of tracks and echonest_metrics on track_id values
echo_tracks = pd.merge(left = tracks[['track_id', 'genre_top']], right=echonest_metrics, on='track_id')

# %%
echo_tracks.head()
# Out:
#    track_id genre_top  acousticness  danceability    energy  instrumentalness  \
# 0       153      Rock      0.988306      0.255661  0.979774          0.973006
# 1       154      Rock      0.970135      0.352946  0.023852          0.957113
# 2       155      Rock      0.981657      0.142249  0.912122          0.967294
# 3       169      Rock      0.989141      0.225978  0.722835          0.263076
# 4       170      Rock      0.886660      0.298518  0.744333          0.920950
#
#    liveness  speechiness   tempo   valence
# 0  0.121342     0.051740  90.241  0.034018
# 1  0.113261     0.032177  53.758  0.035632
# 2  0.363510     0.087527  91.912  0.034325
# 3  0.092371     0.053406  94.322  0.028347
# 4  0.139587     0.088781  97.880  0.073548

# %%
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   genre_top         4802 non-null   object
#  2   acousticness      4802 non-null   float64
#  3   danceability      4802 non-null   float64
#  4   energy            4802 non-null   float64
#  5   instrumentalness  4802 non-null   float64
#  6   liveness          4802 non-null   float64
#  7   speechiness       4802 non-null   float64
#  8   tempo             4802 non-null   float64
#  9   valence           4802 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
#2.Pairwise relationships between continuous variables

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_d4f2d_row0_col0, #T_d4f2d_row1_col1, #T_d4f2d_row2_col2, #T_d4f2d_row3_col3, #T_d4f2d_row4_col4, #T_d4f2d_row5_col5, #T_d4f2d_row6_col6, #T_d4f2d_row7_col7, #T_d4f2d_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d4f2d_row0_col1, #T_d4f2d_row1_col0, #T_d4f2d_row1_col3, #T_d4f2d_row2_col5, #T_d4f2d_row2_col7, #T_d4f2d_row4_col2, #T_d4f2d_row4_col6, #T_d4f2d_row4_col8, #T_d4f2d_row6_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d4f2d_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_d4f2d_row0_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_d4f2d_row0_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_d4f2d_row0_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_d4f2d_row0_col6, #T_d4f2d_row8_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_d4f2d_row0_col7, #T_d4f2d_row1_col7 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_d4f2d_row0_col8, #T_d4f2d_row3_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_d4f2d_row1_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_d4f2d_row1_col4, #T_d4f2d_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_d4f2d_row1_col5, #T_d4f2d_row2_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_d4f2d_row1_col6, #T_d4f2d_row6_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_d4f2d_row1_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_d4f2d_row2_col0, #T_d4f2d_row5_col0, #T_d4f2d_row5_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_d4f2d_row2_col1, #T_d4f2d_row6_col0, #T_d4f2d_row7_col0, #T_d4f2d_row7_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_d4f2d_row2_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_d4f2d_row2_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_d4f2d_row2_col8 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_d4f2d_row3_col0, #T_d4f2d_row7_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_d4f2d_row3_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_d4f2d_row3_col2, #T_d4f2d_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d4f2d_row3_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_d4f2d_row3_col5, #T_d4f2d_row5_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_d4f2d_row3_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_d4f2d_row3_col8, #T_d4f2d_row4_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_d4f2d_row4_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_d4f2d_row4_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_d4f2d_row4_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d4f2d_row5_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_d4f2d_row5_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_d4f2d_row5_col4, #T_d4f2d_row6_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_d4f2d_row5_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_d4f2d_row5_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_d4f2d_row6_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_d4f2d_row6_col3, #T_d4f2d_row6_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_d4f2d_row6_col8 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_d4f2d_row7_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_d4f2d_row7_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d4f2d_row7_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_d4f2d_row7_col8 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_d4f2d_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_d4f2d_row8_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d4f2d_row8_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_d4f2d_row8_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_d4f2d_row8_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d4f2d_row8_col6 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_d4f2d_row8_col7 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_d4f2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4f2d_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_d4f2d_level0_col1" class="col_heading level0 col1" >acousticness</th>
#       <th id="T_d4f2d_level0_col2" class="col_heading level0 col2" >danceability</th>
#       <th id="T_d4f2d_level0_col3" class="col_heading level0 col3" >energy</th>
#       <th id="T_d4f2d_level0_col4" class="col_heading level0 col4" >instrumentalness</th>
#       <th id="T_d4f2d_level0_col5" class="col_heading level0 col5" >liveness</th>
#       <th id="T_d4f2d_level0_col6" class="col_heading level0 col6" >speechiness</th>
#       <th id="T_d4f2d_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_d4f2d_level0_col8" class="col_heading level0 col8" >valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4f2d_level0_row0" class="row_heading level0 row0" >track_id</th>
#       <td id="T_d4f2d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d4f2d_row0_col1" class="data row0 col1" >-0.372282</td>
#       <td id="T_d4f2d_row0_col2" class="data row0 col2" >0.049454</td>
#       <td id="T_d4f2d_row0_col3" class="data row0 col3" >0.140703</td>
#       <td id="T_d4f2d_row0_col4" class="data row0 col4" >-0.275623</td>
#       <td id="T_d4f2d_row0_col5" class="data row0 col5" >0.048231</td>
#       <td id="T_d4f2d_row0_col6" class="data row0 col6" >-0.026995</td>
#       <td id="T_d4f2d_row0_col7" class="data row0 col7" >-0.025392</td>
#       <td id="T_d4f2d_row0_col8" class="data row0 col8" >0.010070</td>
#     </tr>
#     <tr>
#       <th id="T_d4f2d_level0_row1" class="row_heading level0 row1" >acousticness</th>
#       <td id="T_d4f2d_row1_col0" class="data row1 col0" >-0.372282</td>
#       <td id="T_d4f2d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d4f2d_row1_col2" class="data row1 col2" >-0.028954</td>
#       <td id="T_d4f2d_row1_col3" class="data row1 col3" >-0.281619</td>
#       <td id="T_d4f2d_row1_col4" class="data row1 col4" >0.194780</td>
#       <td id="T_d4f2d_row1_col5" class="data row1 col5" >-0.019991</td>
#       <td id="T_d4f2d_row1_col6" class="data row1 col6" >0.072204</td>
#       <td id="T_d4f2d_row1_col7" class="data row1 col7" >-0.026310</td>
#       <td id="T_d4f2d_row1_col8" class="data row1 col8" >-0.013841</td>
#     </tr>
#     <tr>
#       <th id="T_d4f2d_level0_row2" class="row_heading level0 row2" >danceability</th>
#       <td id="T_d4f2d_row2_col0" class="data row2 col0" >0.049454</td>
#       <td id="T_d4f2d_row2_col1" class="data row2 col1" >-0.028954</td>
#       <td id="T_d4f2d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d4f2d_row2_col3" class="data row2 col3" >-0.242032</td>
#       <td id="T_d4f2d_row2_col4" class="data row2 col4" >-0.255217</td>
#       <td id="T_d4f2d_row2_col5" class="data row2 col5" >-0.106584</td>
#       <td id="T_d4f2d_row2_col6" class="data row2 col6" >0.276206</td>
#       <td id="T_d4f2d_row2_col7" class="data row2 col7" >-0.242089</td>
#       <td id="T_d4f2d_row2_col8" class="data row2 col8" >0.473165</td>
#     </tr>
#     <tr>
#       <th id="T_d4f2d_level0_row3" class="row_heading level0 row3" >energy</th>
#       <td id="T_d4f2d_row3_col0" class="data row3 col0" >0.140703</td>
#       <td id="T_d4f2d_row3_col1" class="data row3 col1" >-0.281619</td>
#       <td id="T_d4f2d_row3_col2" class="data row3 col2" >-0.242032</td>
#       <td id="T_d4f2d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d4f2d_row3_col4" class="data row3 col4" >0.028238</td>
#       <td id="T_d4f2d_row3_col5" class="data row3 col5" >0.113331</td>
#       <td id="T_d4f2d_row3_col6" class="data row3 col6" >-0.109983</td>
#       <td id="T_d4f2d_row3_col7" class="data row3 col7" >0.195227</td>
#       <td id="T_d4f2d_row3_col8" class="data row3 col8" >0.038603</td>
#     </tr>
#     <tr>
#       <th id="T_d4f2d_level0_row4" class="row_heading level0 row4" >instrumentalness</th

# %%
#3.Normalizing the feature data

# %%
# Define our features 
features = echo_tracks.drop(['genre_top', 'track_id'], axis = 1)

# Define our labels
labels = echo_tracks['genre_top']

# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)

# %%
#4.Principal Component Analysis on our scaled data

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline

# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_
exp_variance
# Out:
# array([0.24297674, 0.18044316, 0.13650309, 0.12994089, 0.11056248,
#        0.08302245, 0.06923783, 0.04731336])

# %%
# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_),exp_variance)
ax.set_xlabel('Principal Component #')
plt.show()

# %%
#5.Further visualization of PCA

# %%
# Import numpy
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)
cum_exp_variance
# Out:
# array([0.24297674, 0.4234199 , 0.55992299, 0.68986388, 0.80042636,
#        0.88344881, 0.95268664, 1.        ])

# %%
# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot(range(8),cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
plt.show()

# %%
n_components = 7

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %%
pca_projection.shape
# Out:
# (4802, 7)

# %%
#6.Train a decision tree to classify genre

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, stratify = labels)

# Train our decision tree
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(random_state = 10)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels, pred_labels_tree)
# Out:
# 0.8601165695253955

# %%
labels.value_counts()
# Out:
# Rock       3892
# Hip-Hop     910
# Name: genre_top, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_labels, pred_labels_tree)
# Out:
# array([[139,  89],
#        [ 79, 894]], dtype=int64)

# %%
#7.Compare our decision tree to a logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state = 10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.64      0.61      0.62       228
#         Rock       0.91      0.92      0.91       973
#
#     accuracy                           0.86      1201
#    macro avg       0.77      0.76      0.77      1201
# weighted avg       0.86      0.86      0.86      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.81      0.53      0.64       228
#         Rock       0.90      0.97      0.93       973
#
#     accuracy                           0.89      1201
#    macro avg       0.85      0.75      0.79      1201
# weighted avg       0.88      0.89      0.88      1201

# %%
#8 .Balance our data for greater performance

# %%
# Subset only the hip-hop tracks, and then only the rock tracks
hop_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Hip-Hop']
rock_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Rock']
rock_only.head()
# Out:
#    track_id genre_top  acousticness  danceability    energy  instrumentalness  \
# 0       153      Rock      0.988306      0.255661  0.979774          0.973006
# 1       154      Rock      0.970135      0.352946  0.023852          0.957113
# 2       155      Rock      0.981657      0.142249  0.912122          0.967294
# 3       169      Rock      0.989141      0.225978  0.722835          0.263076
# 4       170      Rock      0.886660      0.298518  0.744333          0.920950
#
#    liveness  speechiness   tempo   valence
# 0  0.121342     0.051740  90.241  0.034018
# 1  0.113261     0.032177  53.758  0.035632
# 2  0.363510     0.087527  91.912  0.034325
# 3  0.092371     0.053406  94.322  0.028347
# 4  0.139587     0.088781  97.880  0.073548

# %%
rock_only.shape, hop_only.shape
# Out:
# ((3892, 10), (910, 10))

# %%
# sample the rocks songs to be the same number as there are hip-hop songs
rock_only = rock_only.sample(n= hop_only.shape[0])
rock_only.shape, hop_only.shape
# Out:
# ((910, 10), (910, 10))

# %%
# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat([rock_only, hop_only])
rock_hop_bal.shape
# Out:
# (1820, 10)

# %%
    
# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection,
                                                                            labels,
                                                                            stratify = labels,
                                                                            random_state=10)

# %%
#9.Does balancing our dataset improve model bias?

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state = 10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.79      0.78       227
#         Rock       0.78      0.77      0.78       228
#
#     accuracy                           0.78       455
#    macro avg       0.78      0.78      0.78       455
# weighted avg       0.78      0.78      0.78       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.87      0.80      0.83       227
#         Rock       0.81      0.88      0.84       228
#
#     accuracy                           0.84       455
#    macro avg       0.84      0.84      0.84       455
# weighted avg       0.84      0.84      0.84       455

# %%
#10.Using cross-validation to evaluate our models

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# Set up our K-fold cross-validation
kf = KFold(n_splits=10, random_state=10, shuffle=True)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv = kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv = kf)

# Print the mean of each array of scores
print("Decision Tree:", np.mean(tree_score),
      "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.8153846153846154 Logistic Regression: 0.8538461538461538

# %%
#We can see here that our simple Logistic Regression model performed better than the Decision tree model on the balanced Data. 
#We can try more advanced models like Random Forest and SVM later to see if we can improved our results.

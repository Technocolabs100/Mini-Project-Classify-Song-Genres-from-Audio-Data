# %% [markdown]
# # Importing Datasets

# %%
import pandas as pd
fma = pd.read_csv('fma-rock-vs-hiphop.csv')
fma
# Out:
#        track_id  bit_rate  comments        composer         date_created  \
# 0           135    256000         1             NaN  2008-11-26 01:43:26
# 1           136    256000         1             NaN  2008-11-26 01:43:35
# 2           151    192000         0             NaN  2008-11-26 01:44:55
# 3           152    192000         0             NaN  2008-11-26 01:44:58
# 4           153    256000         0  Arc and Sender  2008-11-26 01:45:00
# ...         ...       ...       ...             ...                  ...
# 17729    155063    320000         0             NaN  2017-03-24 19:40:43
# 17730    155064    320000         0             NaN  2017-03-24 19:40:44
# 17731    155065    320000         0             NaN  2017-03-24 19:40:45
# 17732    155066    320000         0             NaN  2017-03-24 19:40:47
# 17733    155247    320000         0         Fleslit  2017-03-29 01:40:28
#
#              date_recorded  duration  favorites genre_top          genres  \
# 0      2008-11-26 00:00:00       837          0      Rock        [45, 58]
# 1      2008-11-26 00:00:00       509          0      Rock        [45, 58]
# 2                      NaN       192          0      Rock            [25]
# 3                      NaN       193          0      Rock            [25]
# 4      2008-11-26 00:00:00       405          5      Rock            [26]
# ...                    ...       ...        ...       ...             ...
# 17729                  NaN       283          3   Hip-Hop       [21, 811]
# 17730                  NaN       250          2   Hip-Hop       [21, 811]
# 17731                  NaN       219          3   Hip-Hop       [21, 811]
# 17732                  NaN       252          6   Hip-Hop       [21, 811]
# 17733                  NaN       211          3   Hip-Hop  [21, 539, 811]
#
#        ... information interest  language_code  \
# 0      ...         NaN     2484             en
# 1      ...         NaN     1948             en
# 2      ...         NaN      701             en
# 3      ...         NaN      637             en
# 4      ...         NaN      354             en
# ...    ...         ...      ...            ...
# 17729  ...         NaN     1283            NaN
# 17730  ...         NaN     1077            NaN
# 17731  ...         NaN     1340            NaN
# 17732  ...         NaN     2065            NaN
# 17733  ...         NaN     1379            NaN
#
#                                                  license listens  lyricist  \
# 0      Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN
# 1      Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN
# 2      Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN
# 3      Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN
# 4      Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN
# ...                                                  ...     ...       ...
# 17729                                        Attribution    1050       NaN
# 17730                                        Attribution     858       NaN
# 17731                                        Attribution    1142       NaN
# 17732                                        Attribution    1474       NaN
# 17733                                        Attribution    1025       NaN
#
#       number  publisher                                               tags  \
# 0          0        NaN                                                 []
# 1          0        NaN                                                 []
# 2          4        NaN                                                 []
# 3         11        NaN                                                 []
# 4          2        NaN                                                 []
# ...      ...        ...                                                ...
# 17729      4        NaN  ['old school beats', '2017 free instrumentals'...
# 17730      2        NaN  ['old school beats', '2017 free instrumentals'...
# 17731      1        NaN  ['old school beats', '2017 free instrumentals'...
# 17732      3        NaN  ['old school beats', '2017 free instrumentals'...
# 17733      0    Fleslit  ['instrumental trap beat', 'love', 'instrument...
#
#                             title
# 0                    Father's Day
# 1      Peel Back The Mountain Sky
# 2                     Untitled 04
# 3                     Untitled 11
# 4              Hundred-Year Flood
# ...                           ...
# 17729                     Been On
# 17730                     Send Me
# 17731                The Question
# 17732                         Roy
# 17733             Love In The Sky
#
# [17734 rows x 21 columns]

# %%
tracks = pd.read_json('echonest-metrics.json')
tracks
# Out:
#        track_id  acousticness  danceability    energy  instrumentalness  \
# 0             2      0.416675      0.675894  0.634476          0.010628
# 1             3      0.374408      0.528643  0.817461          0.001851
# 2             5      0.043567      0.745566  0.701470          0.000697
# 3            10      0.951670      0.658179  0.924525          0.965427
# 4           134      0.452217      0.513238  0.560410          0.019443
# ...         ...           ...           ...       ...               ...
# 13124    124857      0.007592      0.790364  0.719288          0.853114
# 13125    124862      0.041498      0.843077  0.536496          0.865151
# 13126    124863      0.000124      0.609686  0.895136          0.846624
# 13127    124864      0.327576      0.574426  0.548327          0.452867
# 13128    124911      0.993606      0.499339  0.050622          0.945677
#
#        liveness  speechiness    tempo   valence
# 0      0.177647     0.159310  165.922  0.576661
# 1      0.105880     0.461818  126.957  0.269240
# 2      0.373143     0.124595  100.260  0.621661
# 3      0.115474     0.032985  111.562  0.963590
# 4      0.096567     0.525519  114.290  0.894072
# ...         ...          ...      ...       ...
# 13124  0.720715     0.082550  141.332  0.890461
# 13125  0.547949     0.074001  101.975  0.476845
# 13126  0.632903     0.051517  129.996  0.496667
# 13127  0.075928     0.033388  142.009  0.569274
# 13128  0.095965     0.065189  119.965  0.204652
#
# [13129 rows x 9 columns]

# %% [markdown]
# # Merging two files

# %%
echo_fma = tracks.merge(fma[['genre_top', 'track_id']], on='track_id')
echo_fma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %% [markdown]
# # pairwise relationships between continous variable

# %%
corr_tracks = tracks.corr()
corr_tracks.style.background_gradient()
# Out:
# <style type="text/css">
# #T_7251a_row0_col0, #T_7251a_row1_col1, #T_7251a_row2_col2, #T_7251a_row3_col3, #T_7251a_row4_col4, #T_7251a_row5_col5, #T_7251a_row6_col6, #T_7251a_row7_col7, #T_7251a_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7251a_row0_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_7251a_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_7251a_row0_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_7251a_row0_col4, #T_7251a_row1_col0, #T_7251a_row1_col2, #T_7251a_row1_col3, #T_7251a_row1_col7, #T_7251a_row2_col5, #T_7251a_row3_col1, #T_7251a_row4_col0, #T_7251a_row4_col6, #T_7251a_row4_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7251a_row0_col5 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_7251a_row0_col6 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_7251a_row0_col7 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_7251a_row0_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_7251a_row1_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_7251a_row1_col5, #T_7251a_row6_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_7251a_row1_col6, #T_7251a_row6_col8 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_7251a_row1_col8, #T_7251a_row6_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_7251a_row2_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_7251a_row2_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_7251a_row2_col3, #T_7251a_row5_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_7251a_row2_col4, #T_7251a_row6_col7 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_7251a_row2_col6, #T_7251a_row3_col8, #T_7251a_row6_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_7251a_row2_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7251a_row2_col8 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_7251a_row3_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_7251a_row3_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_7251a_row3_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_7251a_row3_col5 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_7251a_row3_col6 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_7251a_row3_col7, #T_7251a_row6_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_7251a_row4_col1 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_7251a_row4_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_7251a_row4_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_7251a_row4_col5 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_7251a_row4_col7, #T_7251a_row7_col5 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_7251a_row5_col0, #T_7251a_row8_col7 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_7251a_row5_col1, #T_7251a_row6_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_7251a_row5_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_7251a_row5_col4 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_7251a_row5_col6, #T_7251a_row8_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_7251a_row5_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_7251a_row5_col8, #T_7251a_row8_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_7251a_row6_col5 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_7251a_row7_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_7251a_row7_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_7251a_row7_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_7251a_row7_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_7251a_row7_col4, #T_7251a_row7_col8 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_7251a_row7_col6 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_7251a_row8_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_7251a_row8_col2 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_7251a_row8_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_7251a_row8_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_7251a_row8_col6 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# </style>
# <table id="T_7251a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7251a_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_7251a_level0_col1" class="col_heading level0 col1" >acousticness</th>
#       <th id="T_7251a_level0_col2" class="col_heading level0 col2" >danceability</th>
#       <th id="T_7251a_level0_col3" class="col_heading level0 col3" >energy</th>
#       <th id="T_7251a_level0_col4" class="col_heading level0 col4" >instrumentalness</th>
#       <th id="T_7251a_level0_col5" class="col_heading level0 col5" >liveness</th>
#       <th id="T_7251a_level0_col6" class="col_heading level0 col6" >speechiness</th>
#       <th id="T_7251a_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_7251a_level0_col8" class="col_heading level0 col8" >valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7251a_level0_row0" class="row_heading level0 row0" >track_id</th>
#       <td id="T_7251a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7251a_row0_col1" class="data row0 col1" >-0.279829</td>
#       <td id="T_7251a_row0_col2" class="data row0 col2" >0.102056</td>
#       <td id="T_7251a_row0_col3" class="data row0 col3" >0.121991</td>
#       <td id="T_7251a_row0_col4" class="data row0 col4" >-0.283206</td>
#       <td id="T_7251a_row0_col5" class="data row0 col5" >-0.004059</td>
#       <td id="T_7251a_row0_col6" class="data row0 col6" >-0.075077</td>
#       <td id="T_7251a_row0_col7" class="data row0 col7" >0.004313</td>
#       <td id="T_7251a_row0_col8" class="data row0 col8" >0.020201</td>
#     </tr>
#     <tr>
#       <th id="T_7251a_level0_row1" class="row_heading level0 row1" >acousticness</th>
#       <td id="T_7251a_row1_col0" class="data row1 col0" >-0.279829</td>
#       <td id="T_7251a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7251a_row1_col2" class="data row1 col2" >-0.189599</td>
#       <td id="T_7251a_row1_col3" class="data row1 col3" >-0.477273</td>
#       <td id="T_7251a_row1_col4" class="data row1 col4" >0.110033</td>
#       <td id="T_7251a_row1_col5" class="data row1 col5" >0.041319</td>
#       <td id="T_7251a_row1_col6" class="data row1 col6" >0.038785</td>
#       <td id="T_7251a_row1_col7" class="data row1 col7" >-0.110701</td>
#       <td id="T_7251a_row1_col8" class="data row1 col8" >-0.085436</td>
#     </tr>
#     <tr>
#       <th id="T_7251a_level0_row2" class="row_heading level0 row2" >danceability</th>
#       <td id="T_7251a_row2_col0" class="data row2 col0" >0.102056</td>
#       <td id="T_7251a_row2_col1" class="data row2 col1" >-0.189599</td>
#       <td id="T_7251a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7251a_row2_col3" class="data row2 col3" >0.045345</td>
#       <td id="T_7251a_row2_col4" class="data row2 col4" >-0.118033</td>
#       <td id="T_7251a_row2_col5" class="data row2 col5" >-0.143339</td>
#       <td id="T_7251a_row2_col6" class="data row2 col6" >0.171311</td>
#       <td id="T_7251a_row2_col7" class="data row2 col7" >-0.094352</td>
#       <td id="T_7251a_row2_col8" class="data row2 col8" >0.428515</td>
#     </tr>
#     <tr>
#       <th id="T_7251a_level0_row3" class="row_heading level0 row3" >energy</th>
#       <td id="T_7251a_row3_col0" class="data row3 col0" >0.121991</td>
#       <td id="T_7251a_row3_col1" class="data row3 col1" >-0.477273</td>
#       <td id="T_7251a_row3_col2" class="data row3 col2" >0.045345</td>
#       <td id="T_7251a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7251a_row3_col4" class="data row3 col4" >-0.002412</td>
#       <td id="T_7251a_row3_col5" class="data row3 col5" >0.045752</td>
#       <td id="T_7251a_row3_col6" class="data row3 col6" >-0.008645</td>
#       <td id="T_7251a_row3_col7" class="data row3 col7" >0.227324</td>
#       <td id="T_7251a_row3_col8" class="data row3 col8" >0.219384</td>
#     </tr>

# %% [markdown]
# # Normalizing the feature data

# %%
# Defining features
features = echo_fma.drop(columns=['genre_top', 'track_id'])
# Defining labels
labels = echo_fma['genre_top']
# Importing standardScaler
from sklearn.preprocessing import StandardScaler
# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scalar.fit_transform(features)

# %% [markdown]
# # Principal Component Analysis on our scaled data

# %%
# Importing plotting module and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# Getting explained variance ratios from PCA class
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_
# plotting explained variance using barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('principal component')
# Out:
# Text(0.5, 0, 'principal component')

# %% [markdown]
# # cumulative explained variance plot

# %%
import numpy as np
# Calculating cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)
# plotting cumulative explained variance
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.85, linestyle='--')
# choose the n_components where about 85% of our variance can be explained
n_components = 6
# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %% [markdown]
# # decision tree

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)
# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)

# %% [markdown]
# # Compare our decision tree to a logistic regression

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression
# Train our logisitic regression
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)
# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)
print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %% [markdown]
# # Balance our data Sets

# %%
# Subset a balanced proportion of data points
hop_only = echo_fma.loc[echo_fma['genre_top'] == 'Hip-Hop']
rock_only = echo_fma.loc[echo_fma['genre_top'] == 'Rock']
# subset only the rock songs, and take a sample the same size as there are hip-hop songs
rock_only = rock_only.sample(hop_only.shape[0], random_state=10)
# concatenate the dataframes hop_only and rock_only
rock_hop_bal = pd.concat([rock_only, hop_only])
# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))
# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)

# %% [markdown]
# # Balancing our dataset improve model bias

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)
# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)
# compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.74      0.73      0.74       230
#         Rock       0.73      0.74      0.73       225
#
#     accuracy                           0.74       455
#    macro avg       0.74      0.74      0.74       455
# weighted avg       0.74      0.74      0.74       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.84      0.80      0.82       230
#         Rock       0.80      0.85      0.83       225
#
#     accuracy                           0.82       455
#    macro avg       0.82      0.82      0.82       455
# weighted avg       0.82      0.82      0.82       455

# %% [markdown]
# # cross-validation

# %%
from sklearn.model_selection import KFold, cross_val_score
# Set up our K-fold cross-validation
kf = KFold(10)
tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)
# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)
# Print the mean of each array o scores
print("Decision Tree:", np.mean(tree_score), "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7489010989010989 Logistic Regression: 0.782967032967033

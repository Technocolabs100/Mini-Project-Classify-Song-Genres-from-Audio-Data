# %% [markdown]
# By Asmae AMARA

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA

# %% [markdown]
# Preparing the dataset

# %%
# Read the datasets 
tracks = pd.read_csv("fma-rock-vs-hiphop.csv")
echonest_metrics = pd.read_json('echonest-metrics.json',precise_float=True)

# %%
tracks.head()
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
#
#          date_recorded  duration  favorites genre_top    genres  ...  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]  ...
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]  ...
# 2                  NaN       192          0      Rock      [25]  ...
# 3                  NaN       193          0      Rock      [25]  ...
# 4  2008-11-26 00:00:00       405          5      Rock      [26]  ...
#
#   information interest  language_code  \
# 0         NaN     2484             en
# 1         NaN     1948             en
# 2         NaN      701             en
# 3         NaN      637             en
# 4         NaN      354             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN     11
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN      2
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
# 3        NaN   []                 Untitled 11
# 4        NaN   []          Hundred-Year Flood
#
# [5 rows x 21 columns]

# %%
echonest_metrics.head()
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3        10      0.951670      0.658179  0.924525          0.965427  0.115474
# 4       134      0.452217      0.513238  0.560410          0.019443  0.096567
#
#    speechiness    tempo   valence
# 0     0.159310  165.922  0.576661
# 1     0.461818  126.957  0.269240
# 2     0.124595  100.260  0.621661
# 3     0.032985  111.562  0.963590
# 4     0.525519  114.290  0.894072

# %%
# Merge the relevant columns of tracks and echonest_metrics
echonest_tracks = pd.merge(echonest_metrics, tracks[["track_id", "genre_top"]], on="track_id")
echonest_tracks.head()
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3       134      0.452217      0.513238  0.560410          0.019443  0.096567
# 4       153      0.988306      0.255661  0.979774          0.973006  0.121342
#
#    speechiness    tempo   valence genre_top
# 0     0.159310  165.922  0.576661   Hip-Hop
# 1     0.461818  126.957  0.269240   Hip-Hop
# 2     0.124595  100.260  0.621661   Hip-Hop
# 3     0.525519  114.290  0.894072   Hip-Hop
# 4     0.051740   90.241  0.034018      Rock

# %%
# Inspect the resultant dataframe
echonest_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
display(echonest_tracks["genre_top"].value_counts())
# Out:
# Rock       3892
# Hip-Hop     910
# Name: genre_top, dtype: int64

# %% [markdown]
# Pairwise relationships between continuous variables

# %%
# Create a correlation matrix
corr_metrics = echonest_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_3d576_row0_col0, #T_3d576_row1_col1, #T_3d576_row2_col2, #T_3d576_row3_col3, #T_3d576_row4_col4, #T_3d576_row5_col5, #T_3d576_row6_col6, #T_3d576_row7_col7, #T_3d576_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3d576_row0_col1, #T_3d576_row1_col0, #T_3d576_row1_col3, #T_3d576_row2_col5, #T_3d576_row2_col7, #T_3d576_row4_col2, #T_3d576_row4_col6, #T_3d576_row4_col8, #T_3d576_row6_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3d576_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_3d576_row0_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_3d576_row0_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_3d576_row0_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_3d576_row0_col6, #T_3d576_row8_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_3d576_row0_col7, #T_3d576_row1_col7 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_3d576_row0_col8, #T_3d576_row3_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_3d576_row1_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_3d576_row1_col4, #T_3d576_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_3d576_row1_col5, #T_3d576_row2_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_3d576_row1_col6, #T_3d576_row6_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_3d576_row1_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_3d576_row2_col0, #T_3d576_row5_col0, #T_3d576_row5_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_3d576_row2_col1, #T_3d576_row6_col0, #T_3d576_row7_col0, #T_3d576_row7_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_3d576_row2_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_3d576_row2_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_3d576_row2_col8 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_3d576_row3_col0, #T_3d576_row7_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_3d576_row3_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_3d576_row3_col2, #T_3d576_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_3d576_row3_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_3d576_row3_col5, #T_3d576_row5_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_3d576_row3_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_3d576_row3_col8, #T_3d576_row4_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_3d576_row4_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_3d576_row4_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_3d576_row4_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_3d576_row5_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_3d576_row5_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_3d576_row5_col4, #T_3d576_row6_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_3d576_row5_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_3d576_row5_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_3d576_row6_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_3d576_row6_col3, #T_3d576_row6_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_3d576_row6_col8 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_3d576_row7_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_3d576_row7_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_3d576_row7_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_3d576_row7_col8 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_3d576_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_3d576_row8_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_3d576_row8_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_3d576_row8_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_3d576_row8_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_3d576_row8_col6 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_3d576_row8_col7 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_3d576">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d576_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_3d576_level0_col1" class="col_heading level0 col1" >acousticness</th>
#       <th id="T_3d576_level0_col2" class="col_heading level0 col2" >danceability</th>
#       <th id="T_3d576_level0_col3" class="col_heading level0 col3" >energy</th>
#       <th id="T_3d576_level0_col4" class="col_heading level0 col4" >instrumentalness</th>
#       <th id="T_3d576_level0_col5" class="col_heading level0 col5" >liveness</th>
#       <th id="T_3d576_level0_col6" class="col_heading level0 col6" >speechiness</th>
#       <th id="T_3d576_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_3d576_level0_col8" class="col_heading level0 col8" >valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d576_level0_row0" class="row_heading level0 row0" >track_id</th>
#       <td id="T_3d576_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3d576_row0_col1" class="data row0 col1" >-0.372282</td>
#       <td id="T_3d576_row0_col2" class="data row0 col2" >0.049454</td>
#       <td id="T_3d576_row0_col3" class="data row0 col3" >0.140703</td>
#       <td id="T_3d576_row0_col4" class="data row0 col4" >-0.275623</td>
#       <td id="T_3d576_row0_col5" class="data row0 col5" >0.048231</td>
#       <td id="T_3d576_row0_col6" class="data row0 col6" >-0.026995</td>
#       <td id="T_3d576_row0_col7" class="data row0 col7" >-0.025392</td>
#       <td id="T_3d576_row0_col8" class="data row0 col8" >0.010070</td>
#     </tr>
#     <tr>
#       <th id="T_3d576_level0_row1" class="row_heading level0 row1" >acousticness</th>
#       <td id="T_3d576_row1_col0" class="data row1 col0" >-0.372282</td>
#       <td id="T_3d576_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3d576_row1_col2" class="data row1 col2" >-0.028954</td>
#       <td id="T_3d576_row1_col3" class="data row1 col3" >-0.281619</td>
#       <td id="T_3d576_row1_col4" class="data row1 col4" >0.194780</td>
#       <td id="T_3d576_row1_col5" class="data row1 col5" >-0.019991</td>
#       <td id="T_3d576_row1_col6" class="data row1 col6" >0.072204</td>
#       <td id="T_3d576_row1_col7" class="data row1 col7" >-0.026310</td>
#       <td id="T_3d576_row1_col8" class="data row1 col8" >-0.013841</td>
#     </tr>
#     <tr>
#       <th id="T_3d576_level0_row2" class="row_heading level0 row2" >danceability</th>
#       <td id="T_3d576_row2_col0" class="data row2 col0" >0.049454</td>
#       <td id="T_3d576_row2_col1" class="data row2 col1" >-0.028954</td>
#       <td id="T_3d576_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3d576_row2_col3" class="data row2 col3" >-0.242032</td>
#       <td id="T_3d576_row2_col4" class="data row2 col4" >-0.255217</td>
#       <td id="T_3d576_row2_col5" class="data row2 col5" >-0.106584</td>
#       <td id="T_3d576_row2_col6" class="data row2 col6" >0.276206</td>
#       <td id="T_3d576_row2_col7" class="data row2 col7" >-0.242089</td>
#       <td id="T_3d576_row2_col8" class="data row2 col8" >0.473165</td>
#     </tr>
#     <tr>
#       <th id="T_3d576_level0_row3" class="row_heading level0 row3" >energy</th>
#       <td id="T_3d576_row3_col0" class="data row3 col0" >0.140703</td>
#       <td id="T_3d576_row3_col1" class="data row3 col1" >-0.281619</td>
#       <td id="T_3d576_row3_col2" class="data row3 col2" >-0.242032</td>
#       <td id="T_3d576_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3d576_row3_col4" class="data row3 col4" >0.028238</td>
#       <td id="T_3d576_row3_col5" class="data row3 col5" >0.113331</td>
#       <td id="T_3d576_row3_col6" class="data row3 col6" >-0.109983</td>
#       <td id="T_3d576_row3_col7" class="data row3 col7" >0.195227</td>
#       <td id="T_3d576_row3_col8" class="data row3 col8" >0.038603</td>
#     </tr>
#     <tr>
#       <th id="T_3d576_level0_row4" class="row_heading level0 row4" >instrumentalness</th

# %%
echonest_tracks.drop(["track_id"], axis=1).describe()
# Out:
#        acousticness  danceability       energy  instrumentalness     liveness  \
# count  4.802000e+03   4802.000000  4802.000000       4802.000000  4802.000000
# mean   4.870600e-01      0.436556     0.625126          0.604096     0.187997
# std    3.681396e-01      0.183502     0.244051          0.376487     0.150562
# min    9.491000e-07      0.051307     0.000279          0.000000     0.025297
# 25%    8.351236e-02      0.296047     0.450757          0.164972     0.104052
# 50%    5.156888e-01      0.419447     0.648374          0.808752     0.123080
# 75%    8.555765e-01      0.565339     0.837016          0.915472     0.215151
# max    9.957965e-01      0.961871     0.999768          0.993134     0.971392
#
#        speechiness        tempo      valence
# count  4802.000000  4802.000000  4802.000000
# mean      0.104877   126.687944     0.453413
# std       0.145934    34.002473     0.266632
# min       0.023234    29.093000     0.014392
# 25%       0.036897    98.000750     0.224617
# 50%       0.049594   124.625500     0.446240
# 75%       0.088290   151.450000     0.666914
# max       0.966177   250.059000     0.983649

# %% [markdown]
# Normalizing the feature data

# %%
# Defining features 
features = echonest_tracks.drop(["genre_top","track_id"], axis=1)
features.head()
# Out:
#    acousticness  danceability    energy  instrumentalness  liveness  \
# 0      0.416675      0.675894  0.634476          0.010628  0.177647
# 1      0.374408      0.528643  0.817461          0.001851  0.105880
# 2      0.043567      0.745566  0.701470          0.000697  0.373143
# 3      0.452217      0.513238  0.560410          0.019443  0.096567
# 4      0.988306      0.255661  0.979774          0.973006  0.121342
#
#    speechiness    tempo   valence
# 0     0.159310  165.922  0.576661
# 1     0.461818  126.957  0.269240
# 2     0.124595  100.260  0.621661
# 3     0.525519  114.290  0.894072
# 4     0.051740   90.241  0.034018

# %%
# Defining our labels
labels = echonest_tracks["genre_top"]
labels.head()
# Out:
# 0    Hip-Hop
# 1    Hip-Hop
# 2    Hip-Hop
# 3    Hip-Hop
# 4       Rock
# Name: genre_top, dtype: object

# %% [markdown]
#  Principal component analysis on our scaled data

# %%
# Scaling the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
pd.DataFrame(scaled_train_features).head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.191210  1.304420  0.038316 -1.576494 -0.068755  0.373034  1.153979
# 1 -0.306036  0.501886  0.788176 -1.599809 -0.545463  2.446155  0.007914
# 2 -1.204813  1.684139  0.312852 -1.602876  1.229828  0.135130 -0.777317
# 3 -0.094655  0.417927 -0.265203 -1.553079 -0.607326  2.882707 -0.364657
# 4  1.361706 -0.985896  1.453323  0.979975 -0.442757 -0.364157 -1.072003
#
#           7
# 0  0.462287
# 1 -0.690811
# 2  0.631077
# 3  1.652859
# 4 -1.573102

# %%
# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

print("Explained variance ratio : \n{}".format(pca.explained_variance_ratio_))
print("\n")
print("Number of components = {}".format(pca.n_components_))  



# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(8), exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Explained variance ratio :
# [0.24297674 0.18044316 0.13650309 0.12994089 0.11056248 0.08302245
#  0.06923783 0.04731336]
#
#
# Number of components = 8
# Text(0.5, 0, 'Principal Component #')

# %% [markdown]
# Further visualization of PCA

# %%
# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot(range(8), cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %% [markdown]
# Train a decision tree to classify the genre

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Create the classification report for both models
from sklearn.metrics import classification_report

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)
class_rep_tree = classification_report(test_labels, pred_labels_tree)
print("Decision Tree: \n", class_rep_tree)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels, pred_labels_tree)
# Out:
# 0.8434637801831807

# %%
labels.value_counts()
# Out:
# Rock       3892
# Hip-Hop     910
# Name: genre_top, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_labels, pred_labels_tree)
# Out:
# array([[140,  95],
#        [ 93, 873]])

# %% [markdown]
# Compare our decision tree model to a logistic regression

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %% [markdown]
# Balance our data for greater performance

# %%
# Subset only the hip-hop tracks, and then only the rock tracks
hop_only = echonest_tracks.loc[echonest_tracks["genre_top"] == "Hip-Hop"]

# sample the rocks songs to be the same number as there are hip-hop songs
rock_only = echonest_tracks.loc[echonest_tracks["genre_top"] == "Rock"].sample(len(hop_only), random_state=10)

# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat([rock_only, hop_only])

# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# %% [markdown]
#  Does balancing our dataset improve model bias?

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state = 10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.74      0.73      0.74       230
#         Rock       0.73      0.74      0.73       225
#
#     accuracy                           0.74       455
#    macro avg       0.74      0.74      0.74       455
# weighted avg       0.74      0.74      0.74       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.84      0.80      0.82       230
#         Rock       0.80      0.85      0.83       225
#
#     accuracy                           0.82       455
#    macro avg       0.82      0.82      0.82       455
# weighted avg       0.82      0.82      0.82       455

# %% [markdown]
# Evaluate the models by use of cross-validation

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(n_splits=10,random_state=10,shuffle=True)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# Train our models using KFold cv
tree_score = cross_val_score(tree,pca_projection,labels,cv=kf)
logit_score = cross_val_score(logreg,pca_projection,labels,cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", np.mean(tree_score),
      "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7719780219780219 Logistic Regression: 0.823076923076923

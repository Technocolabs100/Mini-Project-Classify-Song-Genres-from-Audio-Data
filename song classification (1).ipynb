# %%
import pandas as pd
fma = pd.read_csv('fma-rock-vs-hiphop.csv')
echonest_metrics = pd.read_json('echonest-metrics.json', precise_float=True)
echo_fma = echonest_metrics.merge(tracks[['genre_top', 'track_id']], on='track_id')
echo_fma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
# Create a correlation matrix
corr_metrics = echonest_metrics.corr()
corr_metrics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_e9d37_row0_col0, #T_e9d37_row1_col1, #T_e9d37_row2_col2, #T_e9d37_row3_col3, #T_e9d37_row4_col4, #T_e9d37_row5_col5, #T_e9d37_row6_col6, #T_e9d37_row7_col7, #T_e9d37_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e9d37_row0_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_e9d37_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_e9d37_row0_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_e9d37_row0_col4, #T_e9d37_row1_col0, #T_e9d37_row1_col2, #T_e9d37_row1_col3, #T_e9d37_row1_col7, #T_e9d37_row2_col5, #T_e9d37_row3_col1, #T_e9d37_row4_col0, #T_e9d37_row4_col6, #T_e9d37_row4_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e9d37_row0_col5 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_e9d37_row0_col6 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_e9d37_row0_col7 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e9d37_row0_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_e9d37_row1_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e9d37_row1_col5, #T_e9d37_row6_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_e9d37_row1_col6, #T_e9d37_row6_col8 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e9d37_row1_col8, #T_e9d37_row6_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e9d37_row2_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_e9d37_row2_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_e9d37_row2_col3, #T_e9d37_row5_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_e9d37_row2_col4, #T_e9d37_row6_col7 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_e9d37_row2_col6, #T_e9d37_row3_col8, #T_e9d37_row6_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_e9d37_row2_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e9d37_row2_col8 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_e9d37_row3_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_e9d37_row3_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_e9d37_row3_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_e9d37_row3_col5 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_e9d37_row3_col6 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_e9d37_row3_col7, #T_e9d37_row6_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_e9d37_row4_col1 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_e9d37_row4_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_e9d37_row4_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_e9d37_row4_col5 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_e9d37_row4_col7, #T_e9d37_row7_col5 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_e9d37_row5_col0, #T_e9d37_row8_col7 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_e9d37_row5_col1, #T_e9d37_row6_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_e9d37_row5_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_e9d37_row5_col4 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_e9d37_row5_col6, #T_e9d37_row8_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_e9d37_row5_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_e9d37_row5_col8, #T_e9d37_row8_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_e9d37_row6_col5 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_e9d37_row7_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_e9d37_row7_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e9d37_row7_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e9d37_row7_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_e9d37_row7_col4, #T_e9d37_row7_col8 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_e9d37_row7_col6 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e9d37_row8_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_e9d37_row8_col2 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_e9d37_row8_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_e9d37_row8_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_e9d37_row8_col6 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# </style>
# <table id="T_e9d37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9d37_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_e9d37_level0_col1" class="col_heading level0 col1" >acousticness</th>
#       <th id="T_e9d37_level0_col2" class="col_heading level0 col2" >danceability</th>
#       <th id="T_e9d37_level0_col3" class="col_heading level0 col3" >energy</th>
#       <th id="T_e9d37_level0_col4" class="col_heading level0 col4" >instrumentalness</th>
#       <th id="T_e9d37_level0_col5" class="col_heading level0 col5" >liveness</th>
#       <th id="T_e9d37_level0_col6" class="col_heading level0 col6" >speechiness</th>
#       <th id="T_e9d37_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_e9d37_level0_col8" class="col_heading level0 col8" >valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9d37_level0_row0" class="row_heading level0 row0" >track_id</th>
#       <td id="T_e9d37_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e9d37_row0_col1" class="data row0 col1" >-0.279829</td>
#       <td id="T_e9d37_row0_col2" class="data row0 col2" >0.102056</td>
#       <td id="T_e9d37_row0_col3" class="data row0 col3" >0.121991</td>
#       <td id="T_e9d37_row0_col4" class="data row0 col4" >-0.283206</td>
#       <td id="T_e9d37_row0_col5" class="data row0 col5" >-0.004059</td>
#       <td id="T_e9d37_row0_col6" class="data row0 col6" >-0.075077</td>
#       <td id="T_e9d37_row0_col7" class="data row0 col7" >0.004313</td>
#       <td id="T_e9d37_row0_col8" class="data row0 col8" >0.020201</td>
#     </tr>
#     <tr>
#       <th id="T_e9d37_level0_row1" class="row_heading level0 row1" >acousticness</th>
#       <td id="T_e9d37_row1_col0" class="data row1 col0" >-0.279829</td>
#       <td id="T_e9d37_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e9d37_row1_col2" class="data row1 col2" >-0.189599</td>
#       <td id="T_e9d37_row1_col3" class="data row1 col3" >-0.477273</td>
#       <td id="T_e9d37_row1_col4" class="data row1 col4" >0.110033</td>
#       <td id="T_e9d37_row1_col5" class="data row1 col5" >0.041319</td>
#       <td id="T_e9d37_row1_col6" class="data row1 col6" >0.038785</td>
#       <td id="T_e9d37_row1_col7" class="data row1 col7" >-0.110701</td>
#       <td id="T_e9d37_row1_col8" class="data row1 col8" >-0.085436</td>
#     </tr>
#     <tr>
#       <th id="T_e9d37_level0_row2" class="row_heading level0 row2" >danceability</th>
#       <td id="T_e9d37_row2_col0" class="data row2 col0" >0.102056</td>
#       <td id="T_e9d37_row2_col1" class="data row2 col1" >-0.189599</td>
#       <td id="T_e9d37_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e9d37_row2_col3" class="data row2 col3" >0.045345</td>
#       <td id="T_e9d37_row2_col4" class="data row2 col4" >-0.118033</td>
#       <td id="T_e9d37_row2_col5" class="data row2 col5" >-0.143339</td>
#       <td id="T_e9d37_row2_col6" class="data row2 col6" >0.171311</td>
#       <td id="T_e9d37_row2_col7" class="data row2 col7" >-0.094352</td>
#       <td id="T_e9d37_row2_col8" class="data row2 col8" >0.428515</td>
#     </tr>
#     <tr>
#       <th id="T_e9d37_level0_row3" class="row_heading level0 row3" >energy</th>
#       <td id="T_e9d37_row3_col0" class="data row3 col0" >0.121991</td>
#       <td id="T_e9d37_row3_col1" class="data row3 col1" >-0.477273</td>
#       <td id="T_e9d37_row3_col2" class="data row3 col2" >0.045345</td>
#       <td id="T_e9d37_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e9d37_row3_col4" class="data row3 col4" >-0.002412</td>
#       <td id="T_e9d37_row3_col5" class="data row3 col5" >0.045752</td>
#       <td id="T_e9d37_row3_col6" class="data row3 col6" >-0.008645</td>
#       <td id="T_e9d37_row3_col7" class="data row3 col7" >0.227324</td>
#       <td id="T_e9d37_row3_col8" class="data row3 col8" >0.219384</td>
#     </tr>

# %%
# Define our features
features = echo_fma.drop(columns=['genre_top', 'track_id'])
# Define our labels
labels = echo_fma['genre_top']
# Import the StandardScaler
from sklearn.preprocessing import StandardScaler
# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_
# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %%
import numpy as np
# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)
# Plot the cumulative explained variance and draw a dashed line at 0.85.
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.85, linestyle='--')
# choose the n_components where about 85% of our variance can be explained
n_components = 6
# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)
# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression
# Train our logisitic regression
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)
# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)
print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %%
# Subset a balanced proportion of data points
hop_only = echo_fma.loc[echo_tracks['genre_top'] == 'Hip-Hop']
rock_only = echo_fma.loc[echo_tracks['genre_top'] == 'Rock']
# subset only the rock songs, and take a sample the same size as there are hip-hop songs
rock_only = rock_only.sample(hop_only.shape[0], random_state=10)
# concatenate the dataframes hop_only and rock_only
rock_hop_bal = pd.concat([rock_only, hop_only])
# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))
# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)
# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)
# compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.74      0.73      0.74       230
#         Rock       0.73      0.74      0.73       225
#
#     accuracy                           0.74       455
#    macro avg       0.74      0.74      0.74       455
# weighted avg       0.74      0.74      0.74       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.84      0.80      0.82       230
#         Rock       0.80      0.85      0.83       225
#
#     accuracy                           0.82       455
#    macro avg       0.82      0.82      0.82       455
# weighted avg       0.82      0.82      0.82       455

# %%
from sklearn.model_selection import KFold, cross_val_score
# Set up our K-fold cross-validation
kf = KFold(10)
tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)
# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)
# Print the mean of each array o scores
print("Decision Tree:", np.mean(tree_score), "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7489010989010989 Logistic Regression: 0.782967032967033
